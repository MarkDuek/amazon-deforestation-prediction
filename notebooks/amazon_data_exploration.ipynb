# %%
import numpy as np

# %%
data = np.load('MarkProjetoDL-2025-06-02/DTCB_area.npz', allow_pickle=True)
lst = data.files

for item in lst:
    print(item)
    print(data[item])
# Out:
# arr_0
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1456 stored elements and shape (2583, 3317)>
#   Coords	Values
#   (870, 2935)	0.09640436597331861
#   (870, 2936)	0.017284678483748477
#   (871, 2935)	0.03126200343163585
#   (871, 2949)	0.1518926016324406
#   (871, 2950)	0.039777281219430236
#   (872, 2949)	0.028377288953557542
#   (939, 3295)	0.07327367272573049
#   (944, 2211)	0.06916890443683918
#   (945, 2211)	0.2072955583706196
#   (955, 2277)	0.013425087010949814
#   (955, 2278)	0.03432802168420868
#   (956, 2277)	0.038861118702916864
#   (956, 2278)	0.017583713993313214
#   (964, 2184)	0.06320427698064711
#   (965, 2175)	0.3037295806553076
#   (965, 2176)	0.04080108040519682
#   (966, 2175)	0.004210180499010979
#   (966, 2176)	0.010580446998258532
#   (966, 2190)	0.047455553661228445
#   (966, 2191)	0.0417820355332549
#   (967, 2189)	0.07595019424908743
#   (967, 2190)	0.09935010796906762
#   (967, 2191)	0.06152319828710616
# ...
